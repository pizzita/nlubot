# %%
import pandas as pd
from collections import  Counter
from nltk.corpus import stopwords
import seaborn as sns
import nltk
import spacy

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
execfile("./utils_folder/utils.py")

# %%
corpus = pd.read_csv("corpus.csv")

# %%
corpus.head(3)
# Out:
#    input_id     input_text
# 0         1  buenas noches
# 1         2  buenas tardes
# 2         3    buenos dias

# %%
corpus['input_text'].str.len().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Este metodo mantiene las palabras que no son consideradas stopwords en español, ej: que, por, etc...

# %%
non_spanish_stopwords(corpus['input_text'])

# %% [markdown]
# ### Este metodo a diferencia del anterior lo que hace es mostrar el total de stopwords(en español)

# %%
plot_top_spanish_stopwords(corpus['input_text'])

# %% [markdown]
# ### Este metodo cuenta las palabras y las clasifica según el menor y mayor rango (en este caso 1 palabra es lo mínimo, y 10 es lo máximo)

# %%
word_count_plot(corpus['input_text'])

# %% [markdown]
# ### Análisis de secuencia de palabras (2 palabras por secuencia)

# %%
plot_top_ngrams_barchart(corpus['input_text'], 2)

# %% [markdown]
# ### Análisis de secuencia de palabras (3 palabras por secuencia)

# %%
plot_top_ngrams_barchart(corpus['input_text'], 3)

# %% [markdown]
# ### Nube de palabras (stopwords excluidos)

# %%
plot_wordcloud(corpus['input_text'])

# %% [markdown]
# #### pip install spcay Y LUEGO Y SOLO LUEGO LE DAS AL OTRO python -m spacy download es_core_news_sm
# #### ese modelo es el de español pero eso ya lo viste

# %% [markdown]
# ### Reconocer entidades

# %%
plot_named_entity_barchart(corpus['input_text'])
